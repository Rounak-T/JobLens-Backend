# %%
import numpy as np 
import pandas as pd

# %%
df= pd.read_csv("data/Resume.csv")
df.head()
# Out:
# Running cells with 'venv (3.13.9) (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Github-Repos/AI-Resume-Analyzer/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
